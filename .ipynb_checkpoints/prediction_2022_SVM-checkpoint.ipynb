# %%
import pandas as pd

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.inspection import permutation_importance

# %%
candidats_complet_2014 = pd.read_csv("data/2014/candidats.csv", encoding="ISO-8859-1", sep=";")
candidats_complet_2018 = pd.read_csv("data/2018/candidats.csv", encoding="ISO-8859-1", sep=";")
candidats_complet_2022 = pd.read_csv("data/2022/candidats.csv", encoding="ISO-8859-1", sep=";")

circonscriptions_complet_2014 = pd.read_csv("data/2014/circonscriptions.csv", encoding="ISO-8859-1", sep=";")
circonscriptions_complet_2018 = pd.read_csv("data/2018/circonscriptions.csv", encoding="ISO-8859-1", sep=";")
circonscriptions_complet_2022 = pd.read_csv("data/2022/circonscriptions.csv", encoding="ISO-8859-1", sep=";")

# %%
# Ajustement l'abréviation de la Coalition Avenir Québec qui a changé entre 2018 et 2022
candidats_complet_2022["Abréviation du parti politique"] = candidats_complet_2022["Abréviation du parti politique"].str.replace("C.A.Q.-E.F.L.", "C.A.Q.-É.F.L.")

# Ajustement pour le Parti Conservateur du Québec dont l'abréviation est différente à chaque année
candidats_complet_2014["Abréviation du parti politique"] = candidats_complet_2014["Abréviation du parti politique"].str.replace("É.A.P. - P.C.Q.", "Conservateurs")
candidats_complet_2018["Abréviation du parti politique"] = candidats_complet_2018["Abréviation du parti politique"].str.replace("P.C.Q./C.P.Q.", "Conservateurs")
candidats_complet_2022["Abréviation du parti politique"] = candidats_complet_2022["Abréviation du parti politique"].str.replace("P.C.Q-E.E.D.", "Conservateurs")

# Ajustement pour le Parti Canadien du Québec pour éviter la confusion
candidats_complet_2022["Abréviation du parti politique"] = candidats_complet_2022["Abréviation du parti politique"].str.replace("P.C.Q./C.P.Q", "Canadien")

# %%
candidats_2014 = candidats_complet_2014[['Numéro de la circonscription', 'Abréviation du parti politique', 'Nombre total de votes']]
candidats_2018 = candidats_complet_2018[['Numéro de la circonscription', 'Abréviation du parti politique', 'Nombre total de votes']]

circonscriptions_2014 = circonscriptions_complet_2014[['Numéro de la circonscription', 'Nom de la circonscription', 'Nombre d\'électeurs inscrits', 'Taux de vote rejeté', 'Taux de participation']]
circonscriptions_2018 = circonscriptions_complet_2018[['Numéro de la circonscription', 'Nom de la circonscription', 'Nombre d\'électeurs inscrits', 'Taux de vote rejeté', 'Taux de participation']]

# %%
# Construction du fichier unique
# Première étape : présentement les votes sont organisés par candidats, on va réorganiser par circonscriptions de manière à avoir pour chaque circonscriptions, le nombre de votes par parti
# On en profite pour ajouter un tag à chaque colonne pour bien identifier de quelle année provient la donnée

votes_partis_2014 = candidats_2014.pivot_table(
    index="Numéro de la circonscription",
    columns="Abréviation du parti politique",
    values="Nombre total de votes",
    aggfunc="sum",
    fill_value=0
).reset_index()

votes_partis_2014.columns.name = None
votes_partis_2014 = votes_partis_2014.rename_axis(None, axis=1)
premiere_colonne = votes_partis_2014.columns[0]
nouvelles_colonnes = [premiere_colonne] + [col + '_2014' for col in votes_partis_2014.columns[1:]]
votes_partis_2014.columns = nouvelles_colonnes

votes_partis_2018 = candidats_2018.pivot_table(
    index="Numéro de la circonscription",
    columns="Abréviation du parti politique",
    values="Nombre total de votes",
    aggfunc="sum",
    fill_value=0
).reset_index()

votes_partis_2018.columns.name = None
votes_partis_2018 = votes_partis_2018.rename_axis(None, axis=1)
premiere_colonne = votes_partis_2018.columns[0]
nouvelles_colonnes = [premiere_colonne] + [col + '_2018' for col in votes_partis_2018.columns[1:]]
votes_partis_2018.columns = nouvelles_colonnes

# %%
# Deuxième étape : fusionner les votes avec les informations des circonscriptions
# On élimine ensuite la colonne avec le numéro de la circonscription, qui n'est plus utile

df_2014 = pd.merge(circonscriptions_2014, votes_partis_2014, on="Numéro de la circonscription")
df_2014 = df_2014.drop(columns=['Numéro de la circonscription'])
df_2018 = pd.merge(circonscriptions_2018, votes_partis_2018, on="Numéro de la circonscription")
df_2018 = df_2018.drop(columns=['Numéro de la circonscription'])

# %%
# Troisième étape : fusionner 2014 et 2018 ensemble
# D'abord décider ce qu'on fait avec les circonscriptions différentes, est-ce qu'on les ignore ou est-ce qu'on trouve une correspondance?
# En faisant simplement la fusion (merge), on les ignore
df = pd.merge(df_2014, df_2018, on="Nom de la circonscription")

# %%
# Extraire le vainqueur de 2022 et l'ajouter aux votes des élections précédentes
# Mais on préalable il faut ajouter le nom de la circonscription avec pour la fusion à la prochaine étape
vainqueurs_2022 = candidats_complet_2022[candidats_complet_2022['Nombre de votes en avance'] > 0]
dico_2022 = circonscriptions_complet_2022[['Numéro de la circonscription', 'Nom de la circonscription']]
vainqueurs_2022 = pd.merge(dico_2022, vainqueurs_2022, on="Numéro de la circonscription")
vainqueurs_2022 = vainqueurs_2022[['Nom de la circonscription', 'Abréviation du parti politique']]

# %%
# Ajouter la liste des vainqueurs au dataframe avec les votes
# Encore une fois il faut décider ici si on choisit de conserver les circonscriptions différentes avec 2022
# Si on fait la fusion directement, on choisit de les ignorer
df = pd.merge(df, vainqueurs_2022, on="Nom de la circonscription")
df = df.rename(columns={'Abréviation du parti politique': 'Vainqueur 2022'})

# %%
# Le dataframe est essentiellement prêt
df.columns
# Out:
# Index(['Nom de la circonscription', 'Nombre d'électeurs inscrits_x',
#        'Taux de vote rejeté_x', 'Taux de participation_x', 'B.P._2014',
#        'C.A.Q.-É.F.L._2014', 'Conservateurs_2014', 'Ind_2014', 'M.P.Q._2014',
#        'O.N. - P.I.Q._2014', 'P.I._2014', 'P.L.Q./Q.L.P._2014',
#        'P.M.L.Q._2014', 'P.N._2014', 'P.Q._2014', 'P.S.P._2014', 'P.U.N._2014',
#        'P.V.Q./G.P.Q._2014', 'P.Éq._2014', 'Q.R.D._2014', 'Q.S._2014',
#        'U.C.Q./Q.C.U._2014', 'É.A._2014', 'Nombre d'électeurs inscrits_y',
#        'Taux de vote rejeté_y', 'Taux de participation_y', 'A.P.Q._2018',
#        'B.P._2018', 'C.A.Q.-É.F.L._2018', 'C.I.N.Q._2018', 'C.P.Q._2018',
#        'Conservateurs_2018', 'Ind_2018', 'N.P.D.Q._2018', 'P.Cu.Q._2018',
#        'P.L._2018', 'P.L.Q./Q.L.P._2018', 'P.M.L.Q._2018', 'P.N._2018',
#        'P.Q._2018', 'P.V.Q./G.P.Q._2018', 'P51_2018', 'Q.S._2018', 'V.P._2018',
#        'É.A._2018', 'Vainqueur 2022'],
#       dtype='object')

# %%
# Encoder la variable cible pour l'entraînement

le = LabelEncoder()
df["vainqueur_encodé"] = le.fit_transform(df["Vainqueur 2022"])

# %%
# Monter le modèle pour utiliser les variables afin de prédire le vainqueur de 2022
# Variables prédictives (X) et cible (y)
X = df[[
    'Nombre d\'électeurs inscrits_x', 'Taux de vote rejeté_x', 'Taux de participation_x', 
    'B.P._2014', 'C.A.Q.-É.F.L._2014', 'Ind_2014', 'M.P.Q._2014', 'O.N. - P.I.Q._2014',
    'P.I._2014', 'P.L.Q./Q.L.P._2014', 'P.M.L.Q._2014', 'P.N._2014',
    'P.Q._2014', 'P.S.P._2014', 'P.U.N._2014', 'P.V.Q./G.P.Q._2014',
    'P.Éq._2014', 'Q.R.D._2014', 'Q.S._2014', 'U.C.Q./Q.C.U._2014',
    'É.A._2014', 'Conservateurs_2014', 'Nombre d\'électeurs inscrits_y',
    'Taux de vote rejeté_y', 'Taux de participation_y', 'A.P.Q._2018',
    'B.P._2018', 'C.A.Q.-É.F.L._2018', 'C.I.N.Q._2018', 'C.P.Q._2018',
    'Ind_2018', 'N.P.D.Q._2018', 'Conservateurs_2018', 'P.Cu.Q._2018',
    'P.L._2018', 'P.L.Q./Q.L.P._2018', 'P.M.L.Q._2018', 'P.N._2018',
    'P.Q._2018', 'P.V.Q./G.P.Q._2018', 'P51_2018', 'Q.S._2018', 'V.P._2018',
    'É.A._2018'
]]
y = df["vainqueur_encodé"]

# %%
# Diviser en ensemble d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Normaliser les données
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# Entraîner un SVM avec équilibrage des classes
model = SVC(kernel="rbf", C=1.0, gamma="scale", class_weight="balanced", random_state=42)
model.fit(x_train_scaled, y_train)
# Out:
# SVC(class_weight='balanced', random_state=42)

# %%
# Prédire et évaluer

y_pred = model.predict(x_test_scaled)
print("Précision globale :", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Précision globale : 0.8333333333333334
#                precision    recall  f1-score   support
#
# C.A.Q.-É.F.L.       0.83      0.96      0.89        25
# P.L.Q./Q.L.P.       0.83      0.62      0.71         8
#          P.Q.       0.00      0.00      0.00         1
#          Q.S.       1.00      0.50      0.67         2
#
#      accuracy                           0.83        36
#     macro avg       0.67      0.52      0.57        36
#  weighted avg       0.82      0.83      0.81        36
# /home/mbeaudoin/Documents/TÉLUQ/SCI1402/elections_provinciales/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/mbeaudoin/Documents/TÉLUQ/SCI1402/elections_provinciales/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/mbeaudoin/Documents/TÉLUQ/SCI1402/elections_provinciales/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# On se rend compte que ce modèle a permis de prédire très efficacement les résultats de Québec Solidaire, et assez bien les résultats
# de la CAQ et du PLQ.  Par contre, encore une fois, la situation du PQ n'a pas pu être interprétée.

# %%
# Essayons maintenant avec des données complémentaires.

données = pd.read_csv("data/variables_complémentaires.csv", encoding="UTF-8", sep=";")

# Supprimer les espaces et remplacer les virgules par des points dans toutes les colonnes sauf "Circonscription"
colonnes_a_convertir = [col for col in données.columns if col != 'Circonscription']

for colonne in colonnes_a_convertir:
    données[colonne] = données[colonne].astype(str).str.replace(' ', '').str.replace(',', '.')
    données[colonne] = pd.to_numeric(données[colonne], errors='coerce')

# %%
df = df.rename(columns={'Nom de la circonscription': 'Circonscription'})
df = pd.merge(df, données, on="Circonscription")

# %%
pd.set_option('display.max_rows', None)  # Affiche toutes les lignes
pd.set_option('display.max_columns', None)  # Affiche toutes les colonnes
pd.set_option('display.width', None)  # Ajuste la largeur d'affichage


df.dtypes
# Out:
# Circonscription                                                object
# Nombre d'électeurs inscrits_x                                   int64
# Taux de vote rejeté_x                                         float64
# Taux de participation_x                                       float64
# B.P._2014                                                       int64
# C.A.Q.-É.F.L._2014                                              int64
# Conservateurs_2014                                              int64
# Ind_2014                                                        int64
# M.P.Q._2014                                                     int64
# O.N. - P.I.Q._2014                                              int64
# P.I._2014                                                       int64
# P.L.Q./Q.L.P._2014                                              int64
# P.M.L.Q._2014                                                   int64
# P.N._2014                                                       int64
# P.Q._2014                                                       int64
# P.S.P._2014                                                     int64
# P.U.N._2014                                                     int64
# P.V.Q./G.P.Q._2014                                              int64
# P.Éq._2014                                                      int64
# Q.R.D._2014                                                     int64
# Q.S._2014                                                       int64
# U.C.Q./Q.C.U._2014                                              int64
# É.A._2014                                                       int64
# Nombre d'électeurs inscrits_y                                   int64
# Taux de vote rejeté_y                                         float64
# Taux de participation_y                                       float64
# A.P.Q._2018                                                     int64
# B.P._2018                                                       int64
# C.A.Q.-É.F.L._2018                                              int64
# C.I.N.Q._2018                                                   int64
# C.P.Q._2018                                                     int64
# Conservateurs_2018                                              int64
# Ind_2018                                                        int64
# N.P.D.Q._2018                                                   int64
# P.Cu.Q._2018                                                    int64
# P.L._2018                                                       int64
# P.L.Q./Q.L.P._2018                                              int64
# P.M.L.Q._2018                                                   int64
# P.N._2018                                                       int64
# P.Q._2018                                                       int64
# P.V.Q./G.P.Q._2018                                              int64
# P51_2018                                                        int64
# Q.S._2018                                                       int64
# V.P._2018                                                       int64
# É.A._2018                                                       int64
# Vainqueur 2022                                                 object
# vainqueur_encodé                                                int64
# age_moyen                                                     float64
# age_median                                                    float64
# Nombre_moyen_de_personnes_par_ménage                          float64
# famille_revenu_median                                           int64
# famille_revenu_moyen                                            int64
# Nombre moyen de personnes par famille                         float64
# temps_de_travail_semaines_travaillées_moyennes                float64
# ratio_hommes                                                  float64
# ratio_femmes                                                  float64
# ratio_0-14                                                    float64
# ratio_15-29                                                   float64
# ratio_30-44                                                   float64
# ratio_45-59                                                   float64
# ratio_60-74                                                   float64
# ratio_75-plus                                                 float64
# ratio_maison_individuelle                                     float64
# ratio_maison_jumelée                                          float64
# ratio_maison_rangée                                           float64
# ratio_appartement_pleinpied_ou_duplex                         float64
# ratio_appartement_moinscinqétages                             float64
# ratio_appartement_pluscinqétages                              float64
# ratio_autre_maison                                            float64
# ratio_logement_mobile                                         float64
# ratio_propriétaires                                           float64
# ratio_locataires                                              float64
# ratio_logement_de_bande                                       float64
# ratio_moins30pourcent                                         float64
# ratio_plus30pourcent                                          float64
# ratio_maison_anglais                                          float64
# ratio_maison_français                                         float64
# ratio_maison_non_officielle                                   float64
# ratio_maison_autochtone                                       float64
# ratio_maison_non_autochtone                                   float64
# ratio_maison_français_et_anglais                              float64
# ratio_maison_anglais_et_non_officielle                        float64
# ratio_maison_français_et_non_officielle                       float64
# ratio_maison_anglais_et_français_et_non_officielle            float64
# ratio_maison_non_officielles_multiples                        float64
# ratio_canadiens                                               float64
# ratio_non_canadiens                                           float64
# ratio_1re_generation                                          float64
# ratio_2e_generation                                           float64
# ratio_3e_generation                                           float64
# ratio_bouddhiste                                              float64
# ratio_chrétienne                                              float64
# ratio_nda                                                     float64
# ratio_anabaptiste                                             float64
# ratio_anglicane                                               float64
# ratio_baptiste                                                float64
# ratio_catholique                                              float64
# ratio_orthodoxe_chrétienne                                    float64
# ratio_témoins_jehovah                                         float64
# ratio_saints_derniers_jours                                   float64
# ratio_luthérienne                                             float64
# ratio_méthodiste                                              float64
# ratio_pentecôtiste                                            float64
# ratio_presbytérienne                                          float64
# ratio_réformée                                                float64
# ratio_église_unie                                             float64
# ratio_autres_chrétiennes                                      float64
# ratio_hindous                                                 float64
# ratio_juive                                                   float64
# ratio_musulmane                                               float64
# ratio_sikhe                                                   float64
# ratio_spiritualité                                            float64
# ratio_autres_religions                                        float64
# ratio_aucune_religion                                         float64
# ratio_pas_travaillé                                           float64
# ratio_travail_plein                                           float64
# ratio_travail_partiel                                         float64
# ratio_travailleurs_sans_objet                                 float64
# ratio_travailleurs_permanents                                 float64
# ratio_travailleurs_temporaires                                float64
# ratio_travailleurs_autonomes                                  float64
# ratio_industrie_sans_objet                                    float64
# ratio_industrie_11                                            float64
# ratio_industrie_21                                            float64
# ratio_industrie_22                                            float64
# ratio_industrie_23                                            float64
# ratio_industrie_31_33                                         float64
# ratio_industrie_41                                            float64
# ratio_industrie_44_45                                         float64
# ratio_industrie_48_49                                         float64
# ratio_industrie_51                                            float64
# ratio_industrie_52                                            float64
# ratio_industrie_53                                            float64
# ratio_industrie_54                                            float64
# ratio_industrie_55                                            float64
# ratio_industrie_56                                            float64
# ratio_industrie_61                                            float64
# ratio_industrie_62                                            float64
# ratio_industrie_71                                            float64
# ratio_industrie_72                                            float64
# ratio_industrie_81                                            float64
# ratio_industrie_91                                            float64
# ratio_langue_travail_anglais                                  float64
# ratio_langue_travail_français                                 float64
# ratio_langue_travail_non_officielle                           float64
# ratio_langue_travail_autochtone                               float64
# ratio_langue_travail_non-autochtone                           float64
# ratio_langue_travail_francais_et_anglais                      float64
# ratio_langue_travail_anglais_et_non_officielle                float64
# ratio_langue_travail_français_et_non_officielle               float64
# ratio_langue_travail_français_et_anglais_et_non_officielle    float64
# ratio_langue_travail_non_officielles_multiples                float64
# ratio_transport_automobile                                    float64
# ratio_transport_en_commun                                     float64
# ratio_transport_à_pied                                        float64
# ratio_transport_vélo                                          float64
# ratio_transport_autre                                         float64
# ratio_durée_moins_15                                          float64
# ratio_durée_15_29                                             float64
# ratio_durée_30_44                                             float64
# ratio_durée_45_59                                             float64
# ratio_durée_60_plus                                           float64
# ratio_aucun_diplôme                                           float64
# ratio_des                                                     float64
# ratio_apprenti_métier                                         float64
# ratio_cegep_collège                                           float64
# ratio_université_inférieur_bac                                float64
# ratio_bac                                                     float64
# ratio_supérieur_bac                                           float64
# ratio_medecine_dentaire_opto_vétérinaire                      float64
# ratio_maîtrise                                                float64
# ratio_doctorat                                                float64
# dtype: object

# %%
# Monter le modèle pour utiliser les variables afin de prédire le vainqueur de 2022
# Variables prédictives (X) et cible (y)

# Liste de toutes les colonnes du DataFrame
toutes_colonnes = df.columns.tolist()

# Colonnes à exclure
colonnes_a_exclure = ["Circonscription", "vainqueur_encodé", "Vainqueur 2022"]

# Créer la liste des colonnes pour X
colonnes_X = [col for col in toutes_colonnes if col not in colonnes_a_exclure]

# Créer la variable X
X = df[colonnes_X]
y = df["vainqueur_encodé"]

# %%
# Diviser en ensemble d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Normaliser les données
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
# Entraîner un SVM avec équilibrage des classes
model = SVC(
    kernel="rbf",
    C=1.0,
    gamma="scale",
    class_weight="balanced",
    random_state=42
)
model.fit(x_train_scaled, y_train)
# Out:
# SVC(class_weight='balanced', random_state=42)

# %%
# Prédire et évaluer

y_pred = model.predict(x_test_scaled)
print("Précision globale :", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le.classes_, zero_division=0))
# Out:
# Précision globale : 0.8055555555555556
#                precision    recall  f1-score   support
#
# C.A.Q.-É.F.L.       0.87      0.93      0.90        28
# P.L.Q./Q.L.P.       0.50      0.40      0.44         5
#          P.Q.       0.00      0.00      0.00         2
#          Q.S.       0.50      1.00      0.67         1
#
#      accuracy                           0.81        36
#     macro avg       0.47      0.58      0.50        36
#  weighted avg       0.76      0.81      0.78        36

# %%
# Calculer l'importance des variables
result = permutation_importance(
    model, x_test_scaled, y_test, n_repeats=10, random_state=42
)

# Afficher les résultats
importance_df = pd.DataFrame({
    "variable": X.columns,
    "importance": result.importances_mean,
    "std": result.importances_std
}).sort_values("importance", ascending=False)

print(importance_df)
# Out:
#                                               variable  importance       std
# 41                                           Q.S._2018    0.027778  0.000000
# 37                                           P.N._2018    0.016667  0.013608
# 8                                   O.N. - P.I.Q._2014    0.005556  0.011111
# 30                                  Conservateurs_2018    0.002778  0.008333
# 21                                           É.A._2014    0.002778  0.008333
# 60                                ratio_maison_jumelée    0.002778  0.008333
# 63                   ratio_appartement_moinscinqétages    0.002778  0.008333
# 56                                         ratio_45-59    0.002778  0.008333
# 119                                 ratio_industrie_11    0.002778  0.008333
# 138                                 ratio_industrie_91    0.002778  0.008333
# 120                                 ratio_industrie_21    0.002778  0.008333
# 7                                          M.P.Q._2014    0.000000  0.000000
# 9                                            P.I._2014    0.000000  0.000000
# 13                                           P.Q._2014    0.000000  0.000000
# 14                                         P.S.P._2014    0.000000  0.000000
# 11                                       P.M.L.Q._2014    0.000000  0.000000
# 10                                  P.L.Q./Q.L.P._2014    0.000000  0.000000
# 16                                  P.V.Q./G.P.Q._2014    0.000000  0.000000
# 6                                             Ind_2014    0.000000  0.000000
# 5                                   Conservateurs_2014    0.000000  0.000000
# 18                                         Q.R.D._2014    0.000000  0.000000
# 20                                  U.C.Q./Q.C.U._2014    0.000000  0.000000
# 22                       Nombre d'électeurs inscrits_y    0.000000  0.000000
# 15                                         P.U.N._2014    0.000000  0.000000
# 12                                           P.N._2014    0.000000  0.000000
# 24                             Taux de participation_y    0.000000  0.000000
# 23                               Taux de vote rejeté_y    0.000000  0.000000
# 28                                       C.I.N.Q._2018    0.000000  0.000000
# 26                                           B.P._2018    0.000000  0.000000
# 31                                            Ind_2018    0.000000  0.000000
# 29                                         C.P.Q._2018    0.000000  0.000000
# 32                                       N.P.D.Q._2018    0.000000  0.000000
# 27                                  C.A.Q.-É.F.L._2018    0.000000  0.000000
# 36                                       P.M.L.Q._2018    0.000000  0.000000
# 17                                          P.Éq._2014    0.000000  0.000000
# 19                                           Q.S._2014    0.000000  0.000000
# 0                        Nombre d'électeurs inscrits_x    0.000000  0.000000
# 4                                   C.A.Q.-É.F.L._2014    0.000000  0.000000
# 1                                Taux de vote rejeté_x    0.000000  0.000000
# 3                                            B.P._2014    0.000000  0.000000
# 2                              Taux de participation_x    0.000000  0.000000
# 136                                 ratio_industrie_72    0.000000  0.000000
# 40                                            P51_2018    0.000000  0.000000
# 38                                           P.Q._2018    0.000000  0.000000
# 39                                  P.V.Q./G.P.Q._2018    0.000000  0.000000
# 34                                           P.L._2018    0.000000  0.000000
# 35                                  P.L.Q./Q.L.P._2018    0.000000  0.000000
# 33                                        P.Cu.Q._2018    0.000000  0.000000
# 47                               famille_revenu_median    0.000000  0.000000
# 52                                        ratio_femmes    0.000000  0.000000
# 49               Nombre moyen de personnes par famille    0.000000  0.000000
# 51                                        ratio_hommes    0.000000  0.000000
# 50      temps_de_travail_semaines_travaillées_moyennes    0.000000  0.000000
# 54                                         ratio_15-29    0.000000  0.000000
# 46                Nombre_moyen_de_personnes_par_ménage    0.000000  0.000000
# 44                                           age_moyen    0.000000  0.000000
# 43                                           É.A._2018    0.000000  0.000000
# 65                                  ratio_autre_maison    0.000000  0.000000
# 55                                         ratio_30-44    0.000000  0.000000
# 58                                       ratio_75-plus    0.000000  0.000000
# 57                                         ratio_60-74    0.000000  0.000000
# 59                           ratio_maison_individuelle    0.000000  0.000000
# 61                                 ratio_maison_rangée    0.000000  0.000000
# 62               ratio_appartement_pleinpied_ou_duplex    0.000000  0.000000
# 64                    ratio_appartement_pluscinqétages    0.000000  0.000000
# 69                             ratio_logement_de_bande    0.000000  0.000000
# 66                               ratio_logement_mobile    0.000000  0.000000
# 67                                 ratio_propriétaires    0.000000  0.000000
# 68                                    ratio_locataires    0.000000  0.000000
# 71                                ratio_plus30pourcent    0.000000  0.000000
# 53                                          ratio_0-14    0.000000  0.000000
# 48                                famille_revenu_moyen    0.000000  0.000000
# 45                                          age_median    0.000000  0.000000
# 89                                           ratio_nda    0.000000  0.000000
# 74                         ratio_maison_non_officielle    0.000000  0.000000
# 75                             ratio_maison_autochtone    0.000000  0.000000
# 76                         ratio_maison_non_autochtone    0.000000  0.000000
# 77                    ratio_maison_français_et_anglais    0.000000  0.000000
# 78              ratio_maison_anglais_et_non_officielle    0.000000  0.000000
# 79             ratio_maison_français_et_non_officielle    0.000000  0.000000
# 80   ratio_maison_anglais_et_français_et_non_offici...    0.000000  0.000000
# 81              ratio_maison_non_officielles_multiples    0.000000  0.000000
# 82                                     ratio_canadiens    0.000000  0.000000
# 83                                 ratio_non_canadiens    0.000000  0.000000
# 84                                ratio_1re_generation    0.000000  0.000000
# 85                                 ratio_2e_generation    0.000000  0.000000
# 86                                 ratio_3e_generation    0.000000  0.000000
# 87                                    ratio_bouddhiste    0.000000  0.000000
# 88                                    ratio_chrétienne    0.000000  0.000000
# 97                                   ratio_luthérienne    0.000000  0.000000
# 90                                   ratio_anabaptiste    0.000000  0.000000
# 91                                     ratio_anglicane    0.000000  0.000000
# 92                                      ratio_baptiste    0.000000  0.000000
# 93                                    ratio_catholique    0.000000  0.000000
# 94                          ratio_orthodoxe_chrétienne    0.000000  0.000000
# 95                               ratio_témoins_jehovah    0.000000  0.000000
# 96                         ratio_saints_derniers_jours    0.000000  0.000000
# 101                                     ratio_réformée    0.000000  0.000000
# 98                                    ratio_méthodiste    0.000000  0.000000
# 99                                  ratio_pentecôtiste    0.000000  0.000000
# 100                               ratio_presbytérienne    0.000000  0.000000
# 103                           ratio_autres_chrétiennes    0.000000  0.000000
# 70                               ratio_moins30pourcent    0.000000  0.000000
# 72                                ratio_maison_anglais    0.000000  0.000000
# 73                               ratio_maison_français    0.000000  0.000000
# 153                              ratio_transport_autre    0.000000  0.000000
# 104                                      ratio_hindous    0.000000  0.000000
# 102                                  ratio_église_unie    0.000000  0.000000
# 105                                        ratio_juive    0.000000  0.000000
# 109                             ratio_autres_religions    0.000000  0.000000
# 110                              ratio_aucune_religion    0.000000  0.000000
# 107                                        ratio_sikhe    0.000000  0.000000
# 106                                    ratio_musulmane    0.000000  0.000000
# 112                                ratio_travail_plein    0.000000  0.000000
# 111                                ratio_pas_travaillé    0.000000  0.000000
# 113                              ratio_travail_partiel    0.000000  0.000000
# 114                      ratio_travailleurs_sans_objet    0.000000  0.000000
# 116                     ratio_travailleurs_temporaires    0.000000  0.000000
# 115                      ratio_travailleurs_permanents    0.000000  0.000000
# 118                         ratio_industrie_sans_objet    0.000000  0.000000
# 108                                 ratio_spiritualité    0.000000  0.000000
# 121                                 ratio_industrie_22    0.000000  0.000000
# 122                                 ratio_industrie_23    0.000000  0.000000
# 123                              ratio_industrie_31_33    0.000000  0.000000
# 124                                 ratio_industrie_41    0.000000  0.000000
# 125                              ratio_industrie_44_45    0.000000  0.000000
# 126                              ratio_industrie_48_49    0.000000  0.000000
# 127                                 ratio_industrie_51    0.000000  0.000000
# 128                                 ratio_industrie_52    0.000000  0.000000
# 129                                 ratio_industrie_53    0.000000  0.000000
# 130                                 ratio_industrie_54    0.000000  0.000000
# 131                                 ratio_industrie_55    0.000000  0.000000
# 132                                 ratio_industrie_56    0.000000  0.000000
# 133                                 ratio_industrie_61    0.000000  0.000000
# 134                                 ratio_industrie_62    0.000000  0.000000
# 135                                 ratio_industrie_71    0.000000  0.000000
# 117                       ratio_travailleurs_autonomes    0.000000  0.000000
# 161                              ratio_apprenti_métier    0.000000  0.000000
# 137                                 ratio_industrie_81    0.000000  0.000000
# 139                       ratio_langue_travail_anglais    0.000000  0.000000
# 140                      ratio_langue_travail_français    0.000000  0.000000
# 141                ratio_langue_travail_non_officielle    0.000000  0.000000
# 142                    ratio_langue_travail_autochtone    0.000000  0.000000
# 143                ratio_langue_travail_non-autochtone    0.000000  0.000000
# 144           ratio_langue_travail_francais_et_anglais    0.000000  0.000000
# 145     ratio_langue_travail_anglais_et_non_officielle    0.000000  0.000000
# 146    ratio_langue_travail_français_et_non_officielle    0.000000  0.000000
# 147  ratio_langue_travail_français_et_anglais_et_no...    0.000000  0.000000
# 148     ratio_langue_travail_non_officielles_multiples    0.000000  0.000000
# 149                         ratio_transport_automobile    0.000000  0.000000
# 150                          ratio_transport_en_commun    0.000000  0.000000
# 151                             ratio_transport_à_pied    0.000000  0.000000
# 152                               ratio_transport_vélo    0.000000  0.000000
# 165                                ratio_supérieur_bac    0.000000  0.000000
# 154                               ratio_durée_moins_15    0.000000  0.000000
# 155                                  ratio_durée_15_29    0.000000  0.000000
# 156                                  ratio_durée_30_44    0.000000  0.000000
# 157                                  ratio_durée_45_59    0.000000  0.000000
# 158                                ratio_durée_60_plus    0.000000  0.000000
# 159                                ratio_aucun_diplôme    0.000000  0.000000
# 160                                          ratio_des    0.000000  0.000000
# 167                                     ratio_maîtrise    0.000000  0.000000
# 162                                ratio_cegep_collège    0.000000  0.000000
# 163                     ratio_université_inférieur_bac    0.000000  0.000000
# 164                                          ratio_bac    0.000000  0.000000
# 168                                     ratio_doctorat    0.000000  0.000000
# 166           ratio_medecine_dentaire_opto_vétérinaire    0.000000  0.000000
# 25                                         A.P.Q._2018   -0.002778  0.008333
# 42                                           V.P._2018   -0.013889  0.018634
